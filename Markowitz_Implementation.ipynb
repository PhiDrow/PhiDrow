# %% [markdown]
# <a href="https://colab.research.google.com/github/PhiDrow/PhiDrow/blob/main/Markowitz_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-cd129ab3-e10a-463f-8120-8f2e7bfea457" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd129ab3-e10a-463f-8120-8f2e7bfea457">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_excel("BBCA 1.1.24-31.12.24.xlsx")
df.head()
df = pd.read_excel("BBNI 1.1.24-31.12.24.xlsx")
df.head()
df = pd.read_excel("BBRI 1.1.24-31.12.24.xlsx")
df.head()
df = pd.read_excel("BMRI 1.1.24-31.12.24.xlsx")
df.head()
# Out:
#           Date      Open      High       Low   \
# 0           NaN       NaN       NaN       NaN
# 1  Dec 30, 2024  5,675.00  5,750.00  5,650.00
# 2  Dec 27, 2024  5,750.00  5,850.00  5,750.00
# 3  Dec 24, 2024  5,825.00  5,875.00  5,750.00
# 4  Dec 23, 2024  5,800.00  5,875.00  5,725.00
#
#                               Close   \
# 0  Close price adjusted for splits.
# 1                           5,700.00
# 2                           5,800.00
# 3                           5,750.00
# 4                           5,825.00
#
#                                           Adj Close      Volume
# 0  Adjusted close price adjusted for splits and d...         NaN
# 1                                           5,178.97  96,782,100
# 2                                           5,269.83  46,126,800
# 3                                           5,224.40  41,240,900
# 4                                           5,292.54  82,910,100

# %%
import pandas as pd

df = pd.read_excel("BBCA 1.1.24-31.12.24.xlsx")
df.head()
# Out:
#           Date      Open      High       Low   \
# 0           NaN       NaN       NaN       NaN
# 1  Dec 30, 2024  9,800.00  9,825.00  9,675.00
# 2  Dec 27, 2024  9,800.00  9,825.00  9,725.00
# 3  Dec 24, 2024  9,850.00  9,900.00  9,750.00
# 4  Dec 23, 2024  9,700.00  9,850.00  9,700.00
#
#                               Close   \
# 0  Close price adjusted for splits.
# 1                           9,675.00
# 2                           9,800.00
# 3                           9,750.00
# 4                           9,775.00
#
#                                           Adj Close      Volume
# 0  Adjusted close price adjusted for splits and d...         NaN
# 1                                           9,324.55  56,350,100
# 2                                           9,445.03  24,016,700
# 3                                           9,396.84  32,415,700
# 4                                           9,420.93  43,292,100

# %%
import pandas as pd

df = pd.read_excel("BBNI 1.1.24-31.12.24.xlsx")
df.head()
# Out:
#           Date      Open      High       Low   \
# 0           NaN       NaN       NaN       NaN
# 1  Dec 30, 2024  4,340.00  4,380.00  4,270.00
# 2  Dec 27, 2024  4,380.00  4,430.00  4,360.00
# 3  Dec 24, 2024  4,380.00  4,400.00  4,340.00
# 4  Dec 23, 2024  4,320.00  4,390.00  4,320.00
#
#                               Close   \
# 0  Close price adjusted for splits.
# 1                           4,350.00
# 2                           4,360.00
# 3                           4,380.00
# 4                           4,380.00
#
#                                           Adj Close      Volume
# 0  Adjusted close price adjusted for splits and d...         NaN
# 1                                           3,992.38  43,899,600
# 2                                           4,001.56  22,838,700
# 3                                           4,019.92  21,458,900
# 4                                           4,019.92  43,668,100

# %%
import pandas as pd
df = pd.read_excel("BBRI 1.1.24-31.12.24.xlsx")
df.head()
# Out:
#           Date           Open      High       Low   \
# 0           NaN            NaN       NaN       NaN
# 1  Dec 30, 2024       4,080.00  4,120.00  4,070.00
# 2  Dec 27, 2024  135 Dividend        NaN       NaN
# 3  Dec 27, 2024       4,100.00  4,120.00  4,080.00
# 4  Dec 24, 2024       4,220.00  4,250.00  4,170.00
#
#                               Close   \
# 0  Close price adjusted for splits.
# 1                           4,080.00
# 2                                NaN
# 3                           4,100.00
# 4                           4,200.00
#
#                                           Adj Close       Volume
# 0  Adjusted close price adjusted for splits and d...          NaN
# 1                                           3,856.24  153,934,700
# 2                                                NaN          NaN
# 3                                           3,875.15  143,104,400
# 4                                           3,842.07  199,536,100

# %%
import pandas as pd

df = pd.read_excel("BMRI 1.1.24-31.12.24.xlsx")
df.head()
# Out:
#           Date      Open      High       Low   \
# 0           NaN       NaN       NaN       NaN
# 1  Dec 30, 2024  5,675.00  5,750.00  5,650.00
# 2  Dec 27, 2024  5,750.00  5,850.00  5,750.00
# 3  Dec 24, 2024  5,825.00  5,875.00  5,750.00
# 4  Dec 23, 2024  5,800.00  5,875.00  5,725.00
#
#                               Close   \
# 0  Close price adjusted for splits.
# 1                           5,700.00
# 2                           5,800.00
# 3                           5,750.00
# 4                           5,825.00
#
#                                           Adj Close      Volume
# 0  Adjusted close price adjusted for splits and d...         NaN
# 1                                           5,178.97  96,782,100
# 2                                           5,269.83  46,126,800
# 3                                           5,224.40  41,240,900
# 4                                           5,292.54  82,910,100

# %%
import pandas as pd

df_bbca = pd.read_excel("BBCA 1.1.24-31.12.24.xlsx")
df_bbni = pd.read_excel("BBNI 1.1.24-31.12.24.xlsx")
df_bbri = pd.read_excel("BBRI 1.1.24-31.12.24.xlsx")
df_bmri = pd.read_excel("BMRI 1.1.24-31.12.24.xlsx")

print("BBCA DataFrame head:")
display(df_bbca.head())

print("\nBBNI DataFrame head:")
display(df_bbni.head())

print("\nBBRI DataFrame head:")
display(df_bbri.head())

print("\nBMRI DataFrame head:")
display(df_bmri.head())
# Out:
# BBCA DataFrame head:
#           Date      Open      High       Low   \
# 0           NaN       NaN       NaN       NaN
# 1  Dec 30, 2024  9,800.00  9,825.00  9,675.00
# 2  Dec 27, 2024  9,800.00  9,825.00  9,725.00
# 3  Dec 24, 2024  9,850.00  9,900.00  9,750.00
# 4  Dec 23, 2024  9,700.00  9,850.00  9,700.00
#
#                               Close   \
# 0  Close price adjusted for splits.
# 1                           9,675.00
# 2                           9,800.00
# 3                           9,750.00
# 4                           9,775.00
#
#                                           Adj Close      Volume
# 0  Adjusted close price adjusted for splits and d...         NaN
# 1                                           9,324.55  56,350,100
# 2                                           9,445.03  24,016,700
# 3                                           9,396.84  32,415,700
# 4                                           9,420.93  43,292,100
# BBNI DataFrame head:
# ...

# %%
# Function to clean and calculate daily returns for a given DataFrame
def calculate_daily_returns(df, name):
    # Drop the first row which contains descriptive text instead of data
    df = df.iloc[1:].copy()

    # Convert 'Date' to datetime objects and sort
    df['Date'] = pd.to_datetime(df['Date'])
    df = df.sort_values(by='Date').reset_index(drop=True)

    # Clean 'Adj Close' column: remove commas and convert to numeric
    # Using errors='coerce' will turn any unparseable values into NaN
    df['Adj Close'] = df['Adj Close'].astype(str).str.replace(',', '', regex=False)
    df['Adj Close'] = pd.to_numeric(df['Adj Close'], errors='coerce')

    # Calculate daily returns
    df['Daily Return'] = df['Adj Close'].pct_change() * 100

    print(f"\n{name} Daily Returns (first 5 rows with original columns and new 'Daily Return' column):")
    display(df.head())
    return df

# Process each DataFrame
df_bbca = calculate_daily_returns(df_bbca, 'BBCA')
df_bbni = calculate_daily_returns(df_bbni, 'BBNI')
df_bbri = calculate_daily_returns(df_bbri, 'BBRI')
df_bmri = calculate_daily_returns(df_bmri, 'BMRI')
# Out:
# BBCA Daily Returns (first 5 rows with original columns and new 'Daily Return' column):
# /tmp/ipython-input-3053282242.py:16: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['Daily Return'] = df['Adj Close'].pct_change() * 100
#         Date      Open      High       Low     Close  Adj Close      Volume  \
# 0 2024-01-03  9,425.00  9,425.00  9,325.00  9,350.00    8764.63  34,603,300
# 1 2024-01-04  9,400.00  9,475.00  9,375.00  9,475.00    8881.81  56,501,800
# 2 2024-01-05  9,500.00  9,600.00  9,475.00  9,575.00    8975.55  85,290,100
# 3 2024-01-08  9,600.00  9,625.00  9,475.00  9,575.00    8975.55  50,896,000
# 4 2024-01-09  9,600.00  9,625.00  9,575.00  9,625.00    9022.42  59,848,600
#
#    Daily Return
# 0           NaN
# 1      1.336965
# 2      1.055416
# 3      0.000000
# ...

# %%
import pandas as pd

# Function to clean and calculate daily returns for a given DataFrame
def calculate_daily_returns(df, name):
    # Strip whitespace from column names
    df.columns = df.columns.str.strip()

    # Drop the first row which contains descriptive text instead of data
    df = df.iloc[1:].copy()

    # Convert 'Date' to datetime objects and sort
    df['Date'] = pd.to_datetime(df['Date'])
    df = df.sort_values(by='Date').reset_index(drop=True)

    # Clean 'Adj Close' column: remove commas and convert to numeric
    # Using errors='coerce' will turn any unparseable values into NaN
    df['Adj Close'] = df['Adj Close'].astype(str).str.replace(',', '', regex=False)
    df['Adj Close'] = pd.to_numeric(df['Adj Close'], errors='coerce')

    # Calculate daily returns
    df['Daily Return'] = df['Adj Close'].pct_change() * 100

    print(f"\n{name} Daily Returns (first 5 rows with original columns and new 'Daily Return' column):")
    display(df.head())
    return df

# Process each DataFrame
df_bbca = calculate_daily_returns(df_bbca, 'BBCA')
df_bbni = calculate_daily_returns(df_bbni, 'BBNI')
df_bbri = calculate_daily_returns(df_bbri, 'BBRI')
df_bmri = calculate_daily_returns(df_bmri, 'BMRI')
# Out:
# BBCA Daily Returns (first 5 rows with original columns and new 'Daily Return' column):
# /tmp/ipython-input-1503739496.py:21: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['Daily Return'] = df['Adj Close'].pct_change() * 100
#         Date      Open      High       Low     Close  Adj Close      Volume  \
# 0 2024-01-02  9,400.00  9,425.00  9,350.00  9,425.00    8834.94  30,545,200
# 1 2024-01-03  9,425.00  9,425.00  9,325.00  9,350.00    8764.63  34,603,300
# 2 2024-01-04  9,400.00  9,475.00  9,375.00  9,475.00    8881.81  56,501,800
# 3 2024-01-05  9,500.00  9,600.00  9,475.00  9,575.00    8975.55  85,290,100
# 4 2024-01-08  9,600.00  9,625.00  9,475.00  9,575.00    8975.55  50,896,000
#
#    Daily Return
# 0           NaN
# 1     -0.795818
# 2      1.336965
# 3      1.055416
# ...

# %% [markdown]
# **Reasoning**:
# The previous code successfully resolved the KeyError and calculated the daily returns. To explicitly fulfill the verification step of the task, I will display the head of each DataFrame to confirm the presence of the 'Daily Return' column and that the previous error has been resolved.

# %%
print("BBCA DataFrame head with Daily Returns:")
display(df_bbca.head())

print("\nBBNI DataFrame head with Daily Returns:")
display(df_bbni.head())

print("\nBBRI DataFrame head with Daily Returns:")
display(df_bbri.head())

print("\nBMRI DataFrame head with Daily Returns:")
display(df_bmri.head())
# Out:
# BBCA DataFrame head with Daily Returns:
#         Date      Open      High       Low     Close  Adj Close      Volume  \
# 0 2024-01-02  9,400.00  9,425.00  9,350.00  9,425.00    8834.94  30,545,200
# 1 2024-01-03  9,425.00  9,425.00  9,325.00  9,350.00    8764.63  34,603,300
# 2 2024-01-04  9,400.00  9,475.00  9,375.00  9,475.00    8881.81  56,501,800
# 3 2024-01-05  9,500.00  9,600.00  9,475.00  9,575.00    8975.55  85,290,100
# 4 2024-01-08  9,600.00  9,625.00  9,475.00  9,575.00    8975.55  50,896,000
#
#    Daily Return
# 0           NaN
# 1     -0.795818
# 2      1.336965
# 3      1.055416
# 4      0.000000
# BBNI DataFrame head with Daily Returns:
#         Date      Open      High       Low     Close  Adj Close      Volume  \
# 0 2024-01-02  5,375.00  5,375.00  5,300.00  5,375.00    4708.12  20,147,500
# 1 2024-01-03  5,375.00  5,400.00  5,325.00  5,350.00    4686.23  27,547,700
# 2 2024-01-04  5,350.00  5,675.00  5,325.00  5,600.00    4905.21  77,162,400
# ...

# %%
print("BBCA DataFrame (2 Jan - 30 Des):")
display(df_bbca)

print("\nBBNI DataFrame (2 Jan - 30 Des):")
display(df_bbni)

print("\nBBRI DataFrame (2 Jan - 30 Des):")
display(df_bbri)

print("\nBMRI DataFrame (2 Jan - 30 Des):")
display(df_bmri)
# Out:
# BBCA DataFrame (2 Jan - 30 Des):
#           Date      Open      High       Low     Close  Adj Close      Volume  \
# 0   2024-01-02  9,400.00  9,425.00  9,350.00  9,425.00    8834.94  30,545,200
# 1   2024-01-03  9,425.00  9,425.00  9,325.00  9,350.00    8764.63  34,603,300
# 2   2024-01-04  9,400.00  9,475.00  9,375.00  9,475.00    8881.81  56,501,800
# 3   2024-01-05  9,500.00  9,600.00  9,475.00  9,575.00    8975.55  85,290,100
# 4   2024-01-08  9,600.00  9,625.00  9,475.00  9,575.00    8975.55  50,896,000
# ..         ...       ...       ...       ...       ...        ...         ...
# 234 2024-12-20  9,650.00  9,750.00  9,625.00  9,650.00    9300.46  91,576,900
# 235 2024-12-23  9,700.00  9,850.00  9,700.00  9,775.00    9420.93  43,292,100
# 236 2024-12-24  9,850.00  9,900.00  9,750.00  9,750.00    9396.84  32,415,700
# 237 2024-12-27  9,800.00  9,825.00  9,725.00  9,800.00    9445.03  24,016,700
# 238 2024-12-30  9,800.00  9,825.00  9,675.00  9,675.00    9324.55  56,350,100
#
# ...

# %%
expected_return_bbca = df_bbca['Daily Return'].mean()
expected_return_bbni = df_bbni['Daily Return'].mean()
expected_return_bbri = df_bbri['Daily Return'].mean()
expected_return_bmri = df_bmri['Daily Return'].mean()

print(f"Expected Daily Return for BBCA: {expected_return_bbca:.2f}%")
print(f"Expected Daily Return for BBNI: {expected_return_bbni:.2f}%")
print(f"Expected Daily Return for BBRI: {expected_return_bbri:.2f}%")
print(f"Expected Daily Return for BMRI: {expected_return_bmri:.2f}%")
# Out:
# Expected Daily Return for BBCA: 0.03%
# Expected Daily Return for BBNI: -0.05%
# Expected Daily Return for BBRI: -0.09%
# Expected Daily Return for BMRI: 0.01%

# %%
variance_bbca = df_bbca['Daily Return'].var()
variance_bbni = df_bbni['Daily Return'].var()
variance_bbri = df_bbri['Daily Return'].var()
variance_bmri = df_bmri['Daily Return'].var()

print(f"Daily Return Variance for BBCA: {variance_bbca:.2f}")
print(f"Daily Return Variance for BBNI: {variance_bbni:.2f}")
print(f"Daily Return Variance for BBRI: {variance_bbri:.2f}")
print(f"Daily Return Variance for BMRI: {variance_bmri:.2f}")
# Out:
# Daily Return Variance for BBCA: 1.95
# Daily Return Variance for BBNI: 3.51
# Daily Return Variance for BBRI: 3.27
# Daily Return Variance for BMRI: 3.67

# %%
std_dev_bbca = df_bbca['Daily Return'].std()
std_dev_bbni = df_bbni['Daily Return'].std()
std_dev_bbri = df_bbri['Daily Return'].std()
std_dev_bmri = df_bmri['Daily Return'].std()

print(f"Daily Return Standard Deviation for BBCA: {std_dev_bbca:.2f}")
print(f"Daily Return Standard Deviation for BBNI: {std_dev_bbni:.2f}")
print(f"Daily Return Standard Deviation for BBRI: {std_dev_bbri:.2f}")
print(f"Daily Return Standard Deviation for BMRI: {std_dev_bmri:.2f}")
# Out:
# Daily Return Standard Deviation for BBCA: 1.40
# Daily Return Standard Deviation for BBNI: 1.87
# Daily Return Standard Deviation for BBRI: 1.81
# Daily Return Standard Deviation for BMRI: 1.91

# %%
import pandas as pd

# Create a DataFrame with only the 'Daily Return' column for each bank
daily_returns = pd.DataFrame({
    'BBCA_Daily_Return': df_bbca['Daily Return'],
    'BBNI_Daily_Return': df_bbni['Daily Return'],
    'BBRI_Daily_Return': df_bbri['Daily Return'],
    'BMRI_Daily_Return': df_bmri['Daily Return']
})

# Calculate the covariance matrix
covariance_matrix = daily_returns.cov()

print("Covariance Matrix of Daily Returns:")
display(covariance_matrix)
# Out:
# Covariance Matrix of Daily Returns:
#                    BBCA_Daily_Return  BBNI_Daily_Return  BBRI_Daily_Return  \
# BBCA_Daily_Return           1.957952           0.942937           0.257327
# BBNI_Daily_Return           0.942937           3.520242           0.120948
# BBRI_Daily_Return           0.257327           0.120948           3.289248
# BMRI_Daily_Return           1.005141           2.361856           0.082475
#
#                    BMRI_Daily_Return
# BBCA_Daily_Return           1.005141
# BBNI_Daily_Return           2.361856
# BBRI_Daily_Return           0.082475
# BMRI_Daily_Return           3.681383

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Confirm that the daily returns have been successfully calculated for all four bank DataFrames.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# Yes, the daily returns have been successfully calculated for all four bank DataFrames (`df_bbca`, `df_bbni`, `df_bbri`, and `df_bmri`). The 'Daily Return' column is present in the head of each DataFrame, with the first entry correctly displaying as NaN.
#
# ### Data Analysis Key Findings
# *   The `calculate_daily_returns` function was successfully modified to strip whitespace from column names, addressing potential `KeyError` issues.
# *   Daily returns were calculated and added as a new column named 'Daily Return' for all four DataFrames (`df_bbca`, `df_bbni`, `df_bbri`, `df_bmri`).
# *   The previous `KeyError` related to column access was resolved by ensuring column names were clean.
# *   Verification confirmed the presence and correct initial calculation (first value as NaN) of the 'Daily Return' column in the head of each DataFrame.
#
# ### Insights or Next Steps
# *   Ensuring column names are standardized (e.g., by stripping whitespace) is crucial for robust data processing and avoiding common `KeyError` issues in data analysis workflows.
# *   The DataFrames are now ready for further financial analysis, such as volatility calculations, performance comparisons, or risk assessments, using the newly computed daily returns.
